# %%
#Gelombang Sinus Sederhana

# %%
import numpy as np 
import matplotlib.pyplot as plt
t = np.linspace(-3*np.pi, 4*np.pi, 100)
y = np.sin(t)
plt.plot(t/np.pi,y) 
plt.title('Fungsi Sinus')
plt.xlabel('t(sekon)/$\pi$') 

plt.ylabel('Sumbu y(m)')
plt.show()
